# %%
from calcTw import calcTw

# %%
import matplotlib.pyplot as plt

# %%
calc = calcTw(19.8, 0.1, 0.2, 0.005, 100, 273, 10000, 9000, 1,100,1.4,300)

# %%
calc.solve()

# %%
print(calc._M2)
print(calc._T02)
# Out:
# 1.0000000093651182
# 272.3548998675692

# %%
print(len(calc._soln.t))
plt.plot(calc._soln.t,calc._soln.y[0], 'x-')
plt.grid()
plt.show()
# Out:
# 47
